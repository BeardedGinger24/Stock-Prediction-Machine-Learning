# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from keras.layers import Dense, Dropout, Activation, Flatten

# %%
# windows file path
df = pd.read_csv('file:///C:/Users/Mher/TSLA.csv')
df[::10]
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2016-03-28   46.321999   46.962002   45.000000   46.051998   46.051998
# 10    2016-04-11   50.200001   51.798000   49.060001   49.984001   49.984001
# 20    2016-04-25   50.602001   51.476002   50.152000   50.363998   50.363998
# 30    2016-05-09   43.144001   43.230000   41.360001   41.784000   41.784000
# 40    2016-05-23   43.973999   44.520000   43.172001   43.243999   43.243999
# ...          ...         ...         ...         ...         ...         ...
# 1210  2021-01-14  843.390015  863.000000  838.750000  845.000000  845.000000
# 1220  2021-01-29  830.000000  842.409973  780.099976  793.530029  793.530029
# 1230  2021-02-12  801.260010  817.330017  785.330017  816.119995  816.119995
# 1240  2021-03-01  690.109985  719.000000  685.049988  718.429993  718.429993
# 1250  2021-03-15  694.090027  713.179993  684.039978  707.940002  707.940002
#
#         Volume
# 0     19628500
# ...

# %%
features = ['Date', 'Open', 'High', 'Low', 'Adj Close', 'Volume']
X = df[features]
Y= df['Close']

# %%
print(X.head())
print(Y.head())
# Out:
#          Date       Open       High        Low  Adj Close    Volume
# 0  2016-03-28  46.321999  46.962002  45.000000  46.051998  19628500
# 1  2016-03-29  45.978001  46.476002  45.066002  46.026001  20071500
# 2  2016-03-30  47.018002  47.099998  45.299999  45.377998  20165000
# 3  2016-03-31  45.868000  47.484001  45.001999  45.953999  40064500
# 4  2016-04-01  48.966000  49.580002  46.650002  47.518002  79987500
# 0    46.051998
# 1    46.026001
# 2    45.377998
# 3    45.953999
# 4    47.518002
# Name: Close, dtype: float64
